# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 584

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units=imperial&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        response = requests.get(city_url).json()
        # print(response)
        
        # Parse the JSON and retrieve data
        city_weather = response["weather"]

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response["coord"]["lat"]
        city_lng = response["coord"]["lon"]
        city_max_temp = response['main']['temp_max']
        city_humidity = response['main']['humidity']
        city_clouds = response["clouds"]["all"]
        city_wind = response["wind"]["speed"]
        city_country = response["sys"]["country"]
        city_date = response["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | talnakh
# Processing Record 2 of Set 1 | ahumada
# City not found. Skipping...
# Processing Record 3 of Set 1 | lagoa
# Processing Record 4 of Set 1 | east london
# Processing Record 5 of Set 1 | cabo san lucas
# Processing Record 6 of Set 1 | mopipi
# Processing Record 7 of Set 1 | bathsheba
# Processing Record 8 of Set 1 | fort nelson
# Processing Record 9 of Set 1 | aklavik
# Processing Record 10 of Set 1 | tuatapere
# Processing Record 11 of Set 1 | tunduru
# City not found. Skipping...
# Processing Record 12 of Set 1 | khatanga
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | severo-kurilsk
# Processing Record 15 of Set 1 | tulum
# Processing Record 16 of Set 1 | clyde river
# Processing Record 17 of Set 1 | jalu
# Processing Record 18 of Set 1 | bratsk
# Processing Record 19 of Set 1 | ikeda
# Processing Record 20 of Set 1 | ushuaia
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          537
# Lat           537
# Lng           537
# Max Temp      537
# Humidity      537
# Cloudiness    537
# Wind Speed    537
# Country       537
# Date          537
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         talnakh  69.4865   88.3972    -20.07       100         100
# 1           lagoa  39.0500  -27.9833     60.28        77         100
# 2     east london -33.0153   27.9116     63.54        63           0
# 3  cabo san lucas  22.8909 -109.9124     82.62        49          75
# 4          mopipi -21.1833   24.8833     76.91        52          25
#
#    Wind Speed Country        Date
# 0        6.31      RU  1680114791
# 1       26.24      PT  1680114925
# 2        8.05      ZA  1680114926
# 3        8.05      MX  1680114926
# 4        2.98      BW  1680114926

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               talnakh  69.4865   88.3972    -20.07       100         100
# 1                 lagoa  39.0500  -27.9833     60.28        77         100
# 2           east london -33.0153   27.9116     63.54        63           0
# 3        cabo san lucas  22.8909 -109.9124     82.62        49          75
# 4                mopipi -21.1833   24.8833     76.91        52          25
#
#          Wind Speed Country        Date
# City_ID
# 0              6.31      RU  1680114791
# 1             26.24      PT  1680114925
# 2              8.05      ZA  1680114926
# 3              8.05      MX  1680114926
# 4              2.98      BW  1680114926

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

x_values = city_data_df["Lat"]
y_values = city_data_df["Max Temp"]

plt.scatter(x_values,y_values, c="red", alpha=0.5, edgecolors="black")

# Incorporate the other graph properties
plt.title("Latitude vs. Temperature (2023-03-29)")
plt.xlabel("Latitude")
plt.ylabel("Max Tempature (C)")
plt.grid()

# Save the figure
plt.savefig("output_data/01 - Latitude vs. Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df["Lat"]
y_values = city_data_df["Humidity"]

plt.scatter(x_values,y_values, c="red", alpha=0.5, edgecolors="black")

# Incorporate the other graph properties
plt.title("Latitude vs. Humidity (2023-03-29)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/02 - Latitude vs. Humidity.png")


# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df["Lat"]
y_values = city_data_df["Cloudiness"]

plt.scatter(x_values,y_values, c="red", alpha=0.5, edgecolors="black")

# Incorporate the other graph properties
plt.title("Latitude vs. Cloudiness (2023-03-29)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/03 - Latitude vs. Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df["Lat"]
y_values = city_data_df["Wind Speed"]

plt.scatter(x_values,y_values, c="red", alpha=0.5, edgecolors="black")

# Incorporate the other graph properties
plt.title("Latitude vs. Wind Speed (2023-03-29)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()

# Save the figure
plt.savefig("output_data/04 - Latitude vs. Wind Speed.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def linear_regress(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    correlation = st.pearsonr(x_values,y_values)
    print(f"The r-value is: {correlation[0]}")
    
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(x_values.min(),y_values.min()),fontsize=15,color="red")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >=0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               talnakh  69.4865   88.3972    -20.07       100         100
# 1                 lagoa  39.0500  -27.9833     60.28        77         100
# 3        cabo san lucas  22.8909 -109.9124     82.62        49          75
# 5             bathsheba  13.2167  -59.5167     86.61        51          20
# 6           fort nelson  58.8053 -122.7002     30.94        82         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.31      RU  1680114791
# 1             26.24      PT  1680114925
# 3              8.05      MX  1680114926
# 5             19.57      BB  1680114927
# 6             11.50      CA  1680114927

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        east london -33.0153   27.9116     63.54        63           0
# 4             mopipi -21.1833   24.8833     76.91        52          25
# 8          tuatapere -46.1333  167.6833     34.59        92          36
# 10         busselton -33.6500  115.3333     60.89        68          91
# 17           ushuaia -54.8000  -68.3000     40.66        65          40
#
#          Wind Speed Country        Date
# City_ID
# 2              8.05      ZA  1680114926
# 4              2.98      BW  1680114926
# 8              4.52      NZ  1680114927
# 10            14.12      AU  1680114928
# 17            20.71      AR  1680114930

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

linear_regress(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])

plt.title("Temperature vs. Latitude in Northern Hemisphere")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.grid()

plt.savefig("output_data/05 - Temperature vs. Latitude (Northern Hemisphere.png")

plt.show()
# Out:
# The r-value is: -0.8933990896473072

# %%
# Linear regression on Southern Hemisphere

linear_regress(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])

plt.title("Temperature vs. Latitude in Southern Hemisphere")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.grid()

plt.savefig("output_data/06 - Temperature vs. Latitude (Southern Hemisphere.png")

plt.show()
# Out:
# The r-value is: 0.7018598064951849

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There is a negative correlation between temperature and latitude in the Northern Hemisphere.  As we head north from the equator, the temperature decreases. In the Southern Hemisphere, we see a positive correlation between the latitude and temperature. As we head towards the equator from the south, the temperature increases.
#
# Putting both graphs together, the temperature is at its highest at zero degrees latitude and drops the further away you are from the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])

plt.title("Humidity vs. Latitude in Northern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()

plt.savefig("output_data/07 - Humidity vs. Latitude (Northern Hemisphere.png")

plt.show()
# Out:
# The r-value is: 0.31658134115839104

# %%
# Southern Hemisphere
linear_regress(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])

plt.title("Humidity vs. Latitude in Southern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()

plt.savefig("output_data/08 - Humidity vs. Latitude (Southern Hemisphere.png")

plt.show()
# Out:
# The r-value is: 0.3271323500926963

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There is a positive correlation between humidity and latitude in both the Northern and Southern Hemispheres
#
# The humidity increases from the Southern Hemisphere to the Northern Hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])

plt.title("Cloudiness vs. Latitude in Northern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()

plt.savefig("output_data/09 - Cloudiness vs. Latitude (Northern Hemisphere.png")

plt.show()
# Out:
# The r-value is: 0.24521213166442546

# %%
# Southern Hemisphere
linear_regress(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])

plt.title("Cloudiness vs. Latitude in Southern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()

plt.savefig("output_data/10 - Cloudiness vs. Latitude (Southern Hemisphere.png")

plt.show()
# Out:
# The r-value is: 0.24020018829042536

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There is a positive correlation between cloudiness and latitude in both the Northern and Southern Hemispheres
#
# In the Northern Hemisphere, it becomes more cloudy as we go north from the equator.
#
#
# In the Southern Hemisphere, it becomes less cloudy as we go south from the equator.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])

plt.title("Wind Speed vs. Latitude in Northern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()

plt.savefig("output_data/11 - Wind Speed vs. Latitude (Northern Hemisphere.png")

plt.show()
# Out:
# The r-value is: 0.04596314431235541

# %%
# Southern Hemisphere
linear_regress(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])

plt.title("Wind Speed vs. Latitude in Southern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()

plt.savefig("output_data/12 - Wind Speed vs. Latitude (Southern Hemisphere.png")

plt.show()
# Out:
# The r-value is: -0.41250534383254567

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There is a slight positive correlation between wind speed and latitude in both the Northern Hemisphere and can conclude the wind speed barely changes in the Northern Hemisphere.
#
# In the Southern Hemisphere, there is a negative correlation.  The wind speed decreases from the south to the equator.
